# %%
import pandas as pd

# %%
# !pwd
# Out:
# /Users/tovahirsch/Desktop/Capstone

# %%
# !ls
# Out:
# API_SH              files_explore.ipynb

# %% [markdown]
# Topic: The effects of clean water on mortality rates
#
# Goal: To see the impact of clean water on lifespan by studying countries that have
# had water improvements of varying degrees.
#
# MVP: linear regression, random forests
#
# Extra Step: CNN on google earth images to determine if a country has highly polluted water as
# observed through visible signs (water color, beach debris etc)
#
# Risks: correlations (hard to isolate clean water as a predictor when many other factors may
# contribute to poor health, short lifespan in underdeveloped countries)
#
# Datasets: have to be split apart along rows/ still need a more robust dataset for lifespan

# %%
Drink_water_perc = pd.read_csv('./API_SH/API_SH.H2O.BASW.csv')
Drink_water_perc
# Out:
#                                            Data Source  \
# 0                                                  NaN
# 1                                    Last Updated Date
# 2                                                  NaN
# 3                                         Country Name
# 4                                                Aruba
# 5                                          Afghanistan
# 6                                               Angola
# 7                                              Albania
# 8                                              Andorra
# 9                                           Arab World
# 10                                United Arab Emirates
# 11                                           Argentina
# 12                                             Armenia
# 13                                      American Samoa
# 14                                 Antigua and Barbuda
# 15                                           Australia
# ...

# %%
Water_quality_perc = pd.read_csv('./API_SH/API_SH.H2O.SAFE.ZS_DS2_en_csv_v2 3.csv')
Water_quality_perc
# Out:
#                                            Data Source  \
# 0                                                  NaN
# 1                                    Last Updated Date
# 2                                                  NaN
# 3                                         Country Name
# 4                                                Aruba
# 5                                          Afghanistan
# 6                                               Angola
# 7                                              Albania
# 8                                              Andorra
# 9                                           Arab World
# 10                                United Arab Emirates
# 11                                           Argentina
# 12                                             Armenia
# 13                                      American Samoa
# 14                                 Antigua and Barbuda
# 15                                           Australia
# ...

# %%
using_safe_water_perc = pd.read_csv('./API_SH/API_SH.H2O.SMDW.csv')
using_safe_water_perc
# Out:
#                                            Data Source  \
# 0                                                  NaN
# 1                                    Last Updated Date
# 2                                                  NaN
# 3                                         Country Name
# 4                                                Aruba
# 5                                          Afghanistan
# 6                                               Angola
# 7                                              Albania
# 8                                              Andorra
# 9                                           Arab World
# 10                                United Arab Emirates
# 11                                           Argentina
# 12                                             Armenia
# 13                                      American Samoa
# 14                                 Antigua and Barbuda
# 15                                           Australia
# ...

# %%
general_info = pd.read_csv('./API_SH/good data.csv')
general_info
# Out:
#       Country Name Country Code  \
# 0       Arab World          ARB
# 1       Arab World          ARB
# 2       Arab World          ARB
# 3       Arab World          ARB
# 4       Arab World          ARB
# 5       Arab World          ARB
# 6       Arab World          ARB
# 7       Arab World          ARB
# 8       Arab World          ARB
# 9       Arab World          ARB
# 10      Arab World          ARB
# 11      Arab World          ARB
# 12      Arab World          ARB
# 13      Arab World          ARB
# 14      Arab World          ARB
# 15      Arab World          ARB
# 16      Arab World          ARB
# 17      Arab World          ARB
# 18      Arab World          ARB
# 19      Arab World          ARB
# 20      Arab World          ARB
# 21      Arab World          ARB
# 22      Arab World          ARB
# 23      Arab World          ARB
# 24      Arab World          ARB
# 25      Arab World          ARB
# 26      Arab World          ARB
# 27      Arab World          ARB
# ...

# %%
general_info_2 = pd.read_csv('./API_SH/good data2.csv')
general_info_2
# Out:
#       Country Name Country Code  \
# 0       Arab World          ARB
# 1       Arab World          ARB
# 2       Arab World          ARB
# 3       Arab World          ARB
# 4       Arab World          ARB
# 5       Arab World          ARB
# 6       Arab World          ARB
# 7       Arab World          ARB
# 8       Arab World          ARB
# 9       Arab World          ARB
# 10      Arab World          ARB
# 11      Arab World          ARB
# 12      Arab World          ARB
# 13      Arab World          ARB
# 14      Arab World          ARB
# 15      Arab World          ARB
# 16      Arab World          ARB
# 17      Arab World          ARB
# 18      Arab World          ARB
# 19      Arab World          ARB
# 20      Arab World          ARB
# 21      Arab World          ARB
# 22      Arab World          ARB
# 23      Arab World          ARB
# 24      Arab World          ARB
# 25      Arab World          ARB
# 26      Arab World          ARB
# 27      Arab World          ARB
# ...

# %%
general_info_3 = pd.read_csv('./API_SH/SDGData.csv')
general_info_3
# Out:
#       Country Name Country Code  \
# 0       Arab World          ARB
# 1       Arab World          ARB
# 2       Arab World          ARB
# 3       Arab World          ARB
# 4       Arab World          ARB
# 5       Arab World          ARB
# 6       Arab World          ARB
# 7       Arab World          ARB
# 8       Arab World          ARB
# 9       Arab World          ARB
# 10      Arab World          ARB
# 11      Arab World          ARB
# 12      Arab World          ARB
# 13      Arab World          ARB
# 14      Arab World          ARB
# 15      Arab World          ARB
# 16      Arab World          ARB
# 17      Arab World          ARB
# 18      Arab World          ARB
# 19      Arab World          ARB
# 20      Arab World          ARB
# 21      Arab World          ARB
# 22      Arab World          ARB
# 23      Arab World          ARB
# 24      Arab World          ARB
# 25      Arab World          ARB
# 26      Arab World          ARB
# 27      Arab World          ARB
# ...

# %%
Latest_water_withdrawal = pd.read_csv('./API_SH/HNP_StatsCountry.csv')
Latest_water_withdrawal
# Out:
#     Country Code                               Short Name  \
# 0            ABW                                    Aruba
# 1            AFG                              Afghanistan
# 2            AGO                                   Angola
# 3            ALB                                  Albania
# 4            AND                                  Andorra
# 5            ARB                               Arab World
# 6            ARE                     United Arab Emirates
# 7            ARG                                Argentina
# 8            ARM                                  Armenia
# 9            ASM                           American Samoa
# 10           ATG                      Antigua and Barbuda
# 11           AUS                                Australia
# 12           AUT                                  Austria
# 13           AZE                               Azerbaijan
# 14           BDI                                  Burundi
# ...

# %%
Population_info = pd.read_csv('./API_SH/HNP_StatsData.csv')
Population_info
# Out:
#       Country Name Country Code  \
# 0       Arab World          ARB
# 1       Arab World          ARB
# 2       Arab World          ARB
# 3       Arab World          ARB
# 4       Arab World          ARB
# 5       Arab World          ARB
# 6       Arab World          ARB
# 7       Arab World          ARB
# 8       Arab World          ARB
# 9       Arab World          ARB
# 10      Arab World          ARB
# 11      Arab World          ARB
# 12      Arab World          ARB
# 13      Arab World          ARB
# 14      Arab World          ARB
# 15      Arab World          ARB
# 16      Arab World          ARB
# 17      Arab World          ARB
# 18      Arab World          ARB
# 19      Arab World          ARB
# 20      Arab World          ARB
# 21      Arab World          ARB
# 22      Arab World          ARB
# 23      Arab World          ARB
# 24      Arab World          ARB
# 25      Arab World          ARB
# 26      Arab World          ARB
# 27      Arab World          ARB
# ...

# %%
general_info_4 = pd.read_csv('./API_SH/WDIData.csv')
general_info_4
# Out:
#                   Country Name Country Code  \
# 0                   Arab World          ARB
# 1                   Arab World          ARB
# 2                   Arab World          ARB
# 3                   Arab World          ARB
# 4                   Arab World          ARB
# 5                   Arab World          ARB
# 6                   Arab World          ARB
# 7                   Arab World          ARB
# 8                   Arab World          ARB
# 9                   Arab World          ARB
# 10                  Arab World          ARB
# 11                  Arab World          ARB
# 12                  Arab World          ARB
# 13                  Arab World          ARB
# 14                  Arab World          ARB
# 15                  Arab World          ARB
# 16                  Arab World          ARB
# 17                  Arab World          ARB
# 18                  Arab World          ARB
# 19                  Arab World          ARB
# ...

# %%
import pandas as pd
human_developement = pd.read_csv('./API_SH/human_development.csv')
human_developement
# Out:
#      HDI Rank                             Country  \
# 0         1.0                              Norway
# 1         2.0                           Australia
# 2         3.0                         Switzerland
# 3         4.0                             Denmark
# 4         5.0                         Netherlands
# 5         6.0                             Germany
# 6         6.0                             Ireland
# 7         8.0                       United States
# 8         9.0                              Canada
# 9         9.0                         New Zealand
# 10       11.0                           Singapore
# 11       12.0              Hong Kong, China (SAR)
# 12       13.0                       Liechtenstein
# 13       14.0                              Sweden
# 14       14.0                      United Kingdom
# 15       16.0                             Iceland
# 16       17.0                 Korea (Republic of)
# 17       18.0                              Israel
# ...

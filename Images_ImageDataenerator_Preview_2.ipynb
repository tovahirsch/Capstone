# %%
import PIL as pillow
from PIL import Image
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
# Out:
# /anaconda3/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# # ORIGNAL IMAGE

# %%
Lake Presa Vicente Guerrero, Mexico
img = load_img('/Users/tovahirsch/Desktop/Capstone/Pics_by_lat/-98.7457218414528.jpg')
img
# Out:
# <PIL.Image.Image image mode=RGB size=640x400 at 0x182091B278>

# %% [markdown]
# # 21 ADDITIONAL IMAGES PRODUCED THROUGH IMAGEDATAGENERATOR

# %%
img_2 = load_img('/Users/tovahirsch/Desktop/Capstone/preview3/lake_0_264.jpeg')
img_2
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x400 at 0x181456E4A8>

# %%
img_3 = load_img('/Users/tovahirsch/Desktop/Capstone/preview3/lake_0_907.jpeg')
img_3
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x400 at 0x1814602940>

# %%
img_4 = load_img('/Users/tovahirsch/Desktop/Capstone/preview3/lake_0_1177.jpeg')
img_4
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x400 at 0x102D79C50>

# %%
img_5 = load_img('/Users/tovahirsch/Desktop/Capstone/preview3/lake_0_1789.jpeg')
img_5
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x400 at 0x1814602BE0>

# %%
img_6 = load_img('/Users/tovahirsch/Desktop/Capstone/preview3/lake_0_2300.jpeg')
img_6
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x400 at 0x1814602E10>

# %%
img_7 = load_img('/Users/tovahirsch/Desktop/Capstone/preview3/lake_0_3040.jpeg')
img_7
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x400 at 0x18144F3400>

# %%
img_8 = load_img('/Users/tovahirsch/Desktop/Capstone/preview3/lake_0_3196.jpeg')
img_8
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x400 at 0x18144F3320>

# %%
img_9 = load_img('/Users/tovahirsch/Desktop/Capstone/preview3/lake_0_3301.jpeg')
img_9
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x400 at 0x18144F37B8>

# %%
img_10 = load_img('/Users/tovahirsch/Desktop/Capstone/preview3/lake_0_3721.jpeg')
img_10
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x400 at 0x18146027F0>

# %%
img_11 = load_img('/Users/tovahirsch/Desktop/Capstone/preview3/lake_0_3758.jpeg')
img_11
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x400 at 0x18144F39E8>

# %%
img_12 = load_img('/Users/tovahirsch/Desktop/Capstone/preview3/lake_0_4219.jpeg')
img_12
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x400 at 0x18144F3B38>

# %%
img_13 = load_img('/Users/tovahirsch/Desktop/Capstone/preview3/lake_0_4634.jpeg')
img_13
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x400 at 0x18144F3C50>

# %%
img_14 = load_img('/Users/tovahirsch/Desktop/Capstone/preview3/lake_0_5197.jpeg')
img_14
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x400 at 0x18144F3DA0>

# %%
img_15 = load_img('/Users/tovahirsch/Desktop/Capstone/preview3/lake_0_5775.jpeg')
img_15
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x400 at 0x18144F3E10>

# %%
img_16 = load_img('/Users/tovahirsch/Desktop/Capstone/preview3/lake_0_6081.jpeg')
img_16
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x400 at 0x1814628160>

# %%
img_17 = load_img('/Users/tovahirsch/Desktop/Capstone/preview3/lake_0_7415.jpeg')
img_17
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x400 at 0x1814628128>

# %%
img_18 = load_img('/Users/tovahirsch/Desktop/Capstone/preview3/lake_0_7835.jpeg')
img_18
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x400 at 0x18144F3240>

# %%
img_19 = load_img('/Users/tovahirsch/Desktop/Capstone/preview3/lake_0_8731.jpeg')
img_19
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x400 at 0x1814628358>

# %%
img_20 = load_img('/Users/tovahirsch/Desktop/Capstone/preview3/lake_0_8751.jpeg')
img_20
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x400 at 0x18146285C0>

# %%
img_21 = load_img('/Users/tovahirsch/Desktop/Capstone/preview3/lake_0_9191.jpeg')
img_21
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x400 at 0x1814628828>

# %%
img_22 = load_img('/Users/tovahirsch/Desktop/Capstone/preview3/lake_0_9740.jpeg')
img_22
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x400 at 0x18144F3860>
